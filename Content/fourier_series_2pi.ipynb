# %% [markdown]
# # Fourier series of simple functions with period $2\pi$

# %% [markdown]
# This notebook illustrates the Fourier series expansion for simple functions with period $2\pi$. Some examples can be found at:
#
# https://www.math24.net/fourier-series-definition-typical-examples/

# %%
import numpy as np
from scipy.signal import sawtooth, square
import matplotlib.pyplot as plt
import my_functions as mfun

# %% [markdown]
# ### Upward sawtooth function

# %%
nmax = 11
bn_up_sawtooth = mfun.upward_sawtooth_bn(nmax)
x = np.linspace(-10, 10, 101)

plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=1), 'k.', label='upward sawtooth')
for n in range(1, nmax+1, 4):
    fs = mfun.fourier_series_real(x=x, a0=0, an=None, bn=bn_up_sawtooth[:n])
    plt.plot(x, fs, '-', label='n = %d' % n)
plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
nmax = 20
a0_up_sawtooth = 0
an_up_sawtooth = np.zeros(nmax)
bn_up_sawtooth = mfun.upward_sawtooth_bn(nmax)
x = np.linspace(-10, 10, 201)
fs_real_up_sawtooth = mfun.fourier_series_real(x=x, a0=a0_up_sawtooth, 
                                              an=an_up_sawtooth, bn=bn_up_sawtooth)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=1), 'k.', label='up sawtooth')

plt.plot(x, fs_real_up_sawtooth, 'b-', label='fourier real')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('upward sawtooth - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([a0_up_sawtooth, an_up_sawtooth]), 'bo--', label='an')
plt.plot(np.hstack([             0, bn_up_sawtooth]), 'ro--', label='bn')
plt.xticks(ticks=[i for i in range(bn_up_sawtooth.size+1)])
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12)
plt.xlabel('n', fontsize=16)
plt.show()

# %%
c0_up_sawtooth, cn_up_sawtooth = mfun.complex_coefficients(a0_up_sawtooth, 
                                                           an_up_sawtooth, 
                                                           bn_up_sawtooth)

# %%
nmax = cn_up_sawtooth.size
x = np.linspace(-10, 10, 201)
fs_complex_up_sawtooth = mfun.fourier_series_complex(x=x, c0=c0_up_sawtooth, 
                                                     cn=cn_up_sawtooth)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=1), 'k.', label='up sawtooth')

plt.plot(x, fs_complex_up_sawtooth.real, 'b-', label='fourier complex real')
plt.plot(x, fs_complex_up_sawtooth.imag, 'r-', label='fourier complex imag')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('upward sawtooth - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([cn_up_sawtooth[::-1].real,
                    c0_up_sawtooth, 
                    cn_up_sawtooth.real]), 'bo--', label='cn real')
plt.plot(np.hstack([cn_up_sawtooth[::-1].imag,
                    0, 
                    cn_up_sawtooth.imag]), 'ro--', label='cn imag')
plt.xticks(ticks=[i for i in range(2*cn_up_sawtooth.size+1)],
           labels=[i for i in range(-cn_up_sawtooth.size, cn_up_sawtooth.size+1)],
           rotation=70)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('n', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %% [markdown]
# ### Odd square function

# %%
nmax = 11
bn_odd_square = mfun.odd_square_bn(nmax)
x = np.linspace(-10, 10, 101)

plt.figure(figsize=(10,6))
plt.plot(x, 0.5*(square(t=x, duty=0.5) + 1), 'k.', label='odd square')
for n in range(1, nmax+1, 4):
    fs_real_odd_square = mfun.fourier_series_real(x=x, a0=1, an=None, bn=bn_odd_square[:n])
    plt.plot(x, fs_real_odd_square, '-', label='n = %d' % n)
plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
nmax = 20
a0_odd_square = 1
an_odd_square = np.zeros(nmax)
bn_odd_square = mfun.odd_square_bn(nmax)
x = np.linspace(-10, 10, 201)
fs_real_odd_square = mfun.fourier_series_real(x=x, a0=a0_odd_square, 
                                              an=an_odd_square, bn=bn_odd_square)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, 0.5*(square(t=x, duty=0.5) + 1), 'k.', label='odd square')

plt.plot(x, fs_real_odd_square, 'b-', label='fourier real')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('odd square - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([a0_odd_square, an_odd_square]), 'bo--', label='an')
plt.plot(np.hstack([             0, bn_odd_square]), 'ro--', label='bn')
plt.xticks(ticks=[i for i in range(bn_odd_square.size+1)])
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12)
plt.xlabel('n', fontsize=16)
plt.show()

# %%
c0_odd_square, cn_odd_square = mfun.complex_coefficients(a0_odd_square, 
                                                         an_odd_square, 
                                                         bn_odd_square)

# %%
nmax = cn_odd_square.size
x = np.linspace(-10, 10, 201)
fs_complex_odd_square = mfun.fourier_series_complex(x=x, c0=c0_odd_square, 
                                                    cn=cn_odd_square)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, 0.5*(square(t=x, duty=0.5) + 1), 'k.', label='odd square')

plt.plot(x, fs_complex_odd_square.real, 'b-', label='fourier complex real')
plt.plot(x, fs_complex_odd_square.imag, 'r-', label='fourier complex imag')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('odd square - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([cn_odd_square[::-1].real,
                    c0_odd_square, 
                    cn_odd_square.real]), 'bo--', label='cn real')
plt.plot(np.hstack([cn_odd_square[::-1].imag,
                    0, 
                    cn_odd_square.imag]), 'ro--', label='cn imag')
plt.xticks(ticks=[i for i in range(2*cn_odd_square.size+1)],
           labels=[i for i in range(-cn_odd_square.size, cn_odd_square.size+1)],
           rotation=70)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('n', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %% [markdown]
# ### Even triangle function

# %%
nmax = 11
an_even_triangle = mfun.even_triangle_an(nmax)
x = np.linspace(-10, 10, 101)

plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=0.5), 'k.', label='even triangle')
for n in range(1, nmax+1, 4):
    fs = mfun.fourier_series_real(x=x, a0=0, an=an_even_triangle[:n], bn=None)
    plt.plot(x, fs, '-', label='n = %d' % n)
plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
nmax = 20
a0_even_triangle = 0
an_even_triangle = mfun.even_triangle_an(nmax)
bn_even_triangle = np.zeros(nmax)
x = np.linspace(-10, 10, 201)
fs_real_even_triangle = mfun.fourier_series_real(x=x, a0=a0_even_triangle, 
                                                 an=an_even_triangle, bn=bn_even_triangle)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=0.5), 'k.', label='even triangle')

plt.plot(x, fs_real_even_triangle, 'b-', label='fourier real')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('even triangle - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([a0_even_triangle, an_even_triangle]), 'bo--', label='an')
plt.plot(np.hstack([             0, bn_even_triangle]), 'ro--', label='bn')
plt.xticks(ticks=[i for i in range(bn_even_triangle.size+1)])
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12)
plt.xlabel('n', fontsize=16)
plt.show()

# %%
c0_even_triangle, cn_even_triangle = mfun.complex_coefficients(a0_even_triangle, 
                                                               an_even_triangle, 
                                                               bn_even_triangle)

# %%
nmax = cn_even_triangle.size
x = np.linspace(-10, 10, 201)
fs_complex_even_triangle = mfun.fourier_series_complex(x=x, c0=c0_even_triangle, 
                                                       cn=cn_even_triangle)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, sawtooth(t=x-np.pi, width=0.5), 'k.', label='even triangle')

plt.plot(x, fs_complex_even_triangle.real, 'b-', label='fourier complex real')
plt.plot(x, fs_complex_even_triangle.imag, 'r-', label='fourier complex imag')

plt.xticks(ticks=[i*np.pi for i in range(-4, 4)], 
           labels=[('%d $\pi$' % i) for i in range(-4, 4)])
plt.xlim(np.min(x), np.max(x))
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('even triangle - nmax %d' % nmax, fontsize=16)
plt.plot(np.hstack([cn_even_triangle[::-1].real,
                    c0_even_triangle, 
                    cn_even_triangle.real]), 'bo--', label='cn real')
plt.plot(np.hstack([cn_even_triangle[::-1].imag,
                    0, 
                    cn_even_triangle.imag]), 'ro--', label='cn imag')
plt.xticks(ticks=[i for i in range(2*cn_even_triangle.size+1)],
           labels=[i for i in range(-cn_even_triangle.size, cn_even_triangle.size+1)],
           rotation=70)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('n', fontsize=16)
plt.legend(loc='upper right', fontsize=12)
plt.show()
